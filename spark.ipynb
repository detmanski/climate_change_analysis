# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import StructType,StructField,StringType,DateType, IntegerType
spark =SparkSession.builder.appName("climate").getOrCreate()
# Out:
# 23/06/08 08:58:10 WARN Utils: Your hostname, Diannes-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 192.168.2.21 instead (on interface en0)
# 23/06/08 08:58:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/06/08 08:58:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/06/08 08:58:23 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
from pyspark import SparkFiles
surface_temp= "Resources/surface_temp_change_clean.csv"
spark.sparkContext.addFile(surface_temp)
surface_temp_df = spark.read.csv(SparkFiles.get("surface_temp_change_clean.csv"), header=True, inferSchema=True)
surface_temp_df.show()
# Out:
# 23/06/08 08:59:27 WARN SparkContext: The path Resources/surface_temp_change_clean.csv has been added already. Overwriting of added paths is not supported in the current version.
# +--------+--------------------+--------------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+-----+------+------+------+-----+-----+------+-----+-----+------+-----+-----+-----+------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# ...

# %%
spark.sparkContext.addFile("Resources/environment_temp_change_clean.csv")
env_temp_df = spark.read.csv(SparkFiles.get("environment_temp_change_clean.csv"), header=True, inferSchema=True)
env_temp_df.show()
# Out:
# 23/06/08 09:08:49 WARN SparkContext: The path Resources/environment_temp_change_clean.csv has been added already. Overwriting of added paths is not supported in the current version.
# +-----------+---------+------------------+------+------+-----+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+-----+-----+------+------+------+------+-----+------+------+------+--------+
# ...

# %%
spark.sparkContext.addFile("Resources/atmospheric_co2_clean.csv")
atmospheric_co2_df = spark.read.csv(SparkFiles.get("atmospheric_co2_clean.csv"), header=True, inferSchema=True)
atmospheric_co2_df.show()
# Out:
# 23/06/08 09:08:51 WARN SparkContext: The path Resources/atmospheric_co2_clean.csv has been added already. Overwriting of added paths is not supported in the current version.
# +--------+-------+-----------------+-------------------+------+
# |ObjectId|Country|             Unit|               Date|Amount|
# +--------+-------+-----------------+-------------------+------+
# |       1|  World|Parts Per Million|1958-03-01 00:00:00| 315.7|
# |       2|  World|Parts Per Million|1958-04-01 00:00:00|317.45|
# |       3|  World|Parts Per Million|1958-05-01 00:00:00|317.51|
# |       4|  World|Parts Per Million|1958-06-01 00:00:00|317.24|
# |       5|  World|Parts Per Million|1958-07-01 00:00:00|315.86|
# |       6|  World|Parts Per Million|1958-08-01 00:00:00|314.93|
# |       7|  World|Parts Per Million|1958-09-01 00:00:00| 313.2|
# |       8|  World|Parts Per Million|1958-10-01 00:00:00|312.43|
# |       9|  World|Parts Per Million|1958-11-01 00:00:00|313.33|
# ...

# %%
spark.sparkContext.addFile("Resources/disaster_frequency_clean.csv")
disaster_frequency_df = spark.read.csv(SparkFiles.get("disaster_frequency_clean.csv"), header=True, inferSchema=True)
disaster_frequency_df.show()
# Out:
# 23/06/08 09:08:54 WARN SparkContext: The path Resources/disaster_frequency_clean.csv has been added already. Overwriting of added paths is not supported in the current version.
# +--------+--------------------+---------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# |ObjectId|             Country|     Unit|F1980|F1981|F1982|F1983|F1984|F1985|F1986|F1987|F1988|F1989|F1990|F1991|F1992|F1993|F1994|F1995|F1996|F1997|F1998|F1999|F2000|F2001|F2002|F2003|F2004|F2005|F2006|F2007|F2008|F2009|F2010|F2011|F2012|F2013|F2014|F2015|F2016|F2017|F2018|F2019|F2020|F2021|F2022|
# ...

# %%
spark.sparkContext.addFile("Resources/forest_and_carbon_clean.csv")
forest_and_carbon_df = spark.read.csv(SparkFiles.get("forest_and_carbon_clean.csv"), header=True, inferSchema=True)
forest_and_carbon_df.show()
# Out:
# 23/06/08 09:09:12 WARN SparkContext: The path Resources/forest_and_carbon_clean.csv has been added already. Overwriting of added paths is not supported in the current version.
# +--------+--------------------+--------------------+--------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+
# ...

# %%
spark.sparkContext.addFile("Resources/sea_levels_clean.csv")
sea_levels_df = spark.read.csv(SparkFiles.get("sea_levels_clean.csv"), header=True, inferSchema=True)
sea_levels_df.show()
# Out:
# 23/06/08 09:09:16 WARN SparkContext: The path Resources/sea_levels_clean.csv has been added already. Overwriting of added paths is not supported in the current version.
# +--------+-------+-----------+--------------+-------------------+------+
# |ObjectId|Country|       Unit|       Measure|               Date|Amount|
# +--------+-------+-----------+--------------+-------------------+------+
# |       1|  World|Millimeters|   Andaman Sea|1992-12-17 00:00:00|-10.34|
# |       2|  World|Millimeters|   Arabian Sea|1992-12-17 00:00:00|-18.46|
# |       3|  World|Millimeters|Atlantic Ocean|1992-12-17 00:00:00|-15.41|
# |       4|  World|Millimeters|    Baltic Sea|1992-12-17 00:00:00|196.85|
# |       5|  World|Millimeters|    Bay Bengal|1992-12-17 00:00:00|  3.27|
# |       6|  World|Millimeters| Caribbean Sea|1992-12-17 00:00:00|-13.58|
# |       7|  World|Millimeters|   Gulf Mexico|1992-12-17 00:00:00| -3.95|
# |       8|  World|Millimeters|  Indian Ocean|1992-12-17 00:00:00|-27.63|
# ...
